# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)

# %%
import pandas as pd
import json
from sklearn.model_selection import train_test_split
from pandas.io.json import json_normalize
import torch
from transformers import EncoderDecoderModel, AutoTokenizer
from typing import *

# %% [markdown]
# Download Data

# %%
import os
import urllib.request
from tqdm import tqdm

class DownloadProgressBar(tqdm):
  def update_to(self, b=1, bsize=1, tsize=None):
    if tsize is not None:
      self.total = tsize
    self.update(b*bsize - self.n)

def download_url(url, output_path):
  with DownloadProgressBar(unit='B', unit_scale=True, miniters=1, desc=url.split('/')[-1]) as t:
    urllib.request.urlretrieve(url, filename=output_path, reporthook=t.update_to)

def download_data(data_path, url_path, suffix):
  if not os.path.exists(data_path):
    os.makedirs(data_path)

  data_path = os.path.join(data_path,f'{suffix}.json')

  if not os.path.exists(data_path):
    print(f"Downloading CoQA {suffix} data split... (it may take a while)")
    download_url(url=url_path, output_path=data_path)
    print("Download Completed!")

# %%
#Train Data
train_url = "https://nlp.stanford.edu/data/coqa/coqa-train-v1.0.json"
download_data(data_path='coqa',url_path=train_url, suffix='train')

#Test Data
test_url = "https://nlp.stanford.edu/data/coqa/coqa-dev-v1.0.json"
download_data(data_path='coqa', url_path = test_url, suffix='test')

# %%
train_data = json.load((open('/content/coqa/train.json')))
qas = json_normalize(train_data['data'], ['questions'], ['source', 'id', 'story'])
ans = json_normalize(train_data['data'], ['answers'],['id'])
train_df = pd.merge(qas,ans, left_on=['id','turn_id'], right_on=['id','turn_id'])
train_df.loc[10:30,['turn_id','input_text_x', 'input_text_y', 'span_text']]
# Out:
# <ipython-input-28-6ef5e64aca27>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   qas = json_normalize(train_data['data'], ['questions'], ['source', 'id', 'story'])
# <ipython-input-28-6ef5e64aca27>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   ans = json_normalize(train_data['data'], ['answers'],['id'])
#     turn_id                                       input_text_x  \
# 10       11  when were the Secret Archives moved from the r...
# 11       12      how many items are in this secret collection?
# 12       13                       Can anyone use this library?
# 13       14                    what must be requested to view?
# 14       15       what must be requested in person or by mail?
# 15       16                                     of what books?
# 16       17                    What is the Vat the library of?
# 17       18    How many books survived the Pre Lateran period?
# 18       19  what is the point of the project started in 2014?
# 19       20                              what will this allow?
# 20        1                        Where was the Auction held?
# 21        2                            How much did they make?
# 22        3                        How much did they expected?
# 23        4                          WHo buy the Jackson Glove
# 24        5             Where was the buyer of the glove from?
# 25        1                    What did Venters call Lassiter?
# 26        2              Who asked Lassiter to be their rider?
# 27        3                                      Did he agree?
# 28        4                               Why did she ask him?
# 29        5                          Did she tell him as much?
# 30        6                   What was she willing to give up?
#
#                                          input_text_y  \
# 10              at the beginning of the 17th century;
# 11                                            150,000
# 12  anyone who can document their qualifications a...
# 13                                            unknown
# 14                                        Photocopies
# 15         only books published between 1801 and 1990
# 16                                       the Holy See
# 17                               a handful of volumes
# 18                             digitising manuscripts
# 19                          them to be viewed online.
# 20                                     Hard Rock Cafe
# 21                                        $2 million.
# 22                                           $120,000
# 23                                         Hoffman Ma
# 24                                              Macau
# 25                                            gun-man
# 26                                               Jane
# 27                                                Yes
# 28  to take charge of her cattle and horse and ran...
# 29                                                 No
# 30                      Whatever the price to be paid
#
#                                             span_text
# 10  atican Secret Archives were separated from the...
# 11   Vatican Secret Archives were separated from t...
# 12   The Vatican Library is open to anyone who can...
# 13                                            unknown
# 14  Photocopies for private study of pages from bo...
# 15  hotocopies for private study of pages from boo...
# 16    simply the Vat, is the library of the Holy See,
# 17  Pre-Lateran period, comprising the initial day...
# 18  Vatican Library began an initial four-year pro...
# 19         manuscripts, to be made available online.
# 20          Hard Rock Cafe in New York's Times Square
# 21                     reaping a total $2 million. \n
# 22   pre-sale expectations of only $120,000 in sal...
# 23  Hoffman Ma, who bought the glove on behalf of ...
# 24                behalf of Ponte 16 Resort in Macau,
# 25            this gun-man, as Venters had called him
# 26  "Lassiter, will you be my rider?" Jane had ask...
# 27                     "I reckon so," he had replied.
# 28  She wanted him to take charge of her cattle an...
# 29  though she could not have spoken aloud all she...
# 30                      Whatever the price to be paid

# %%
train_df['q_first_word']=train_df['input_text_x'].str.lower().str.extract(r'(\w+)')
train_df['q_first_two_words']=train_df['input_text_x'].str.lower().str.extract(r'^((?:\S+\s+){1}\S+).*')
train_df.groupby('q_first_word').count().sort_values(by='input_text_x',ascending=False).head(30)
# Out:
#               input_text_x  turn_id  bad_turn_x  source     id  story  \
# q_first_word
# what                 32092    32092         114   32092  32092  32092
# who                  15684    15684          45   15684  15684  15684
# how                  10946    10946          37   10946  10946  10946
# did                   7381     7381          19    7381   7381   7381
# where                 7214     7214          21    7214   7214   7214
# was                   5121     5121          30    5121   5121   5121
# when                  4530     4530          10    4530   4530   4530
# is                    3431     3431          16    3431   3431   3431
# why                   2921     2921          13    2921   2921   2921
# does                  2110     2110           5    2110   2110   2110
# and                   2050     2050           3    2050   2050   2050
# which                 1737     1737           3    1737   1737   1737
# were                  1041     1041           5    1041   1041   1041
# are                   1028     1028           5    1028   1028   1028
# in                     979      979           4     979    979    979
# do                     851      851           1     851    851    851
# for                    677      677           3     677    677    677
# by                     418      418           2     418    418    418
# from                   411      411           0     411    411    411
# to                     399      399           0     399    399    399
# has                    383      383           1     383    383    383
# can                    367      367           0     367    367    367
# on                     312      312           0     312    312    312
# had                    301      301           0     301    301    301
# with                   292      292           0     292    292    292
# of                     287      287           2     287    287    287
# whose                  282      282           1     282    282    282
# name                   244      244           0     244    244    244
# anything               230      230           1     230    230    230
# at                     205      205           3     205    205    205
#
#               span_start  span_end  span_text  input_text_y  bad_turn_y  \
# q_first_word
# what               32092     32092      32092         32092         611
# who                15684     15684      15684         15684         301
# how                10946     10946      10946         10946         224
# did                 7381      7381       7381          7381         137
# where               7214      7214       7214          7214         121
# was                 5121      5121       5121          5121         121
# when                4530      4530       4530          4530          83
# is                  3431      3431       3431          3431          76
# why                 2921      2921       2921          2921          65
# does                2110      2110       2110          2110          33
# and                 2050      2050       2050          2050          31
# which               1737      1737       1737          1737          34
# were                1041      1041       1041          1041          27
# are                 1028      1028       1028          1028          22
# in                   979       979        979           979          15
# do                   851       851        851           851          22
# for                  677       677        677           677          11
# by                   418       418        418           418           4
# from                 411       411        411           411           4
# to                   399       399        399           399           3
# has                  383       383        383           383          15
# can                  367       367        367           367           7
# on                   312       312        312           312           5
# had                  301       301        301           301          11
# with                 292       292        292           292           4
# of                   287       287        287           287           2
# whose                282       282        282           282          11
# name                 244       244        244           244           2
# anything             230       230        230           230           4
# at                   205       205        205           205           1
#
#               q_first_two_words
# q_first_word
# what                      31711
# who                       15075
# how                       10662
# did                        7381
# where                      6305
# was                        5121
# when                       3614
# is                         3431
# why                        1885
# does                       2110
# and                        1914
# which                      1720
# were                       1041
# are                        1028
# in                          976
# do                          851
# for                         665
# by                          408
# from                        398
# to                          398
# has                         383
# can                         367
# on                          310
# had                         301
# with                        287
# of                          274
# whose                       265
# name                        238
# anything                    230
# at                          205

# %%
train_df.groupby('q_first_two_words').count().sort_values(by='input_text_x',ascending=False).head(30)
# Out:
#                    input_text_x  turn_id  bad_turn_x  source    id  story  \
# q_first_two_words
# what did                   5622     5622          27    5622  5622   5622
# what was                   5079     5079          10    5079  5079   5079
# what is                    4800     4800          15    4800  4800   4800
# how many                   3692     3692          12    3692  3692   3692
# who was                    3390     3390           9    3390  3390   3390
# who is                     2409     2409          11    2409  2409   2409
# did he                     2366     2366           5    2366  2366   2366
# where did                  1988     1988           3    1988  1988   1988
# when did                   1810     1810           5    1810  1810   1810
# what does                  1797     1797           5    1797  1797   1797
# who did                    1409     1409           5    1409  1409   1409
# where was                  1350     1350           2    1350  1350   1350
# how did                    1308     1308           5    1308  1308   1308
# was he                     1281     1281           7    1281  1281   1281
# how old                    1228     1228           2    1228  1228   1228
# how long                   1185     1185           3    1185  1185   1185
# when was                   1144     1144           1    1144  1144   1144
# where is                   1030     1030           5    1030  1030   1030
# did they                    921      921           6     921   921    921
# was it                      883      883           6     883   883    883
# is it                       881      881           2     881   881    881
# did she                     854      854           1     854   854    854
# what kind                   805      805           5     805   805    805
# what are                    770      770           3     770   770    770
# what happened               699      699           2     699   699    699
# did the                     695      695           2     695   695    695
# how much                    646      646           0     646   646    646
# what were                   641      641           3     641   641    641
# in what                     597      597           1     597   597    597
# does he                     593      593           1     593   593    593
#
#                    span_start  span_end  span_text  input_text_y  bad_turn_y  \
# q_first_two_words
# what did                 5622      5622       5622          5622          97
# what was                 5079      5079       5079          5079         100
# what is                  4800      4800       4800          4800         101
# how many                 3692      3692       3692          3692         108
# who was                  3390      3390       3390          3390          74
# who is                   2409      2409       2409          2409          29
# did he                   2366      2366       2366          2366          40
# where did                1988      1988       1988          1988          40
# when did                 1810      1810       1810          1810          38
# what does                1797      1797       1797          1797          37
# who did                  1409      1409       1409          1409          31
# where was                1350      1350       1350          1350          23
# how did                  1308      1308       1308          1308          22
# was he                   1281      1281       1281          1281          33
# how old                  1228      1228       1228          1228          16
# how long                 1185      1185       1185          1185          17
# when was                 1144      1144       1144          1144          24
# where is                 1030      1030       1030          1030          16
# did they                  921       921        921           921          15
# was it                    883       883        883           883          16
# is it                     881       881        881           881          17
# did she                   854       854        854           854           9
# what kind                 805       805        805           805          15
# what are                  770       770        770           770           9
# what happened             699       699        699           699          14
# did the                   695       695        695           695          25
# how much                  646       646        646           646           9
# what were                 641       641        641           641          13
# in what                   597       597        597           597           6
# does he                   593       593        593           593          10
#
#                    q_first_word
# q_first_two_words
# what did                   5622
# what was                   5079
# what is                    4800
# how many                   3692
# who was                    3390
# who is                     2409
# did he                     2366
# where did                  1988
# when did                   1810
# what does                  1797
# who did                    1409
# where was                  1350
# how did                    1308
# was he                     1281
# how old                    1228
# how long                   1185
# when was                   1144
# where is                   1030
# did they                    921
# was it                      883
# is it                       881
# did she                     854
# what kind                   805
# what are                    770
# what happened               699
# did the                     695
# how much                    646
# what were                   641
# in what                     597
# does he                     593

# %%
train_df = train_df.loc[train_df['input_text_y']!='unknown']
train_df.loc[10:30,['turn_id','input_text_x', 'input_text_y', 'span_text']]
# Out:
#     turn_id                                       input_text_x  \
# 10       11  when were the Secret Archives moved from the r...
# 11       12      how many items are in this secret collection?
# 12       13                       Can anyone use this library?
# 14       15       what must be requested in person or by mail?
# 15       16                                     of what books?
# 16       17                    What is the Vat the library of?
# 17       18    How many books survived the Pre Lateran period?
# 18       19  what is the point of the project started in 2014?
# 19       20                              what will this allow?
# 20        1                        Where was the Auction held?
# 21        2                            How much did they make?
# 22        3                        How much did they expected?
# 23        4                          WHo buy the Jackson Glove
# 24        5             Where was the buyer of the glove from?
# 25        1                    What did Venters call Lassiter?
# 26        2              Who asked Lassiter to be their rider?
# 27        3                                      Did he agree?
# 28        4                               Why did she ask him?
# 29        5                          Did she tell him as much?
# 30        6                   What was she willing to give up?
#
#                                          input_text_y  \
# 10              at the beginning of the 17th century;
# 11                                            150,000
# 12  anyone who can document their qualifications a...
# 14                                        Photocopies
# 15         only books published between 1801 and 1990
# 16                                       the Holy See
# 17                               a handful of volumes
# 18                             digitising manuscripts
# 19                          them to be viewed online.
# 20                                     Hard Rock Cafe
# 21                                        $2 million.
# 22                                           $120,000
# 23                                         Hoffman Ma
# 24                                              Macau
# 25                                            gun-man
# 26                                               Jane
# 27                                                Yes
# 28  to take charge of her cattle and horse and ran...
# 29                                                 No
# 30                      Whatever the price to be paid
#
#                                             span_text
# 10  atican Secret Archives were separated from the...
# 11   Vatican Secret Archives were separated from t...
# 12   The Vatican Library is open to anyone who can...
# 14  Photocopies for private study of pages from bo...
# 15  hotocopies for private study of pages from boo...
# 16    simply the Vat, is the library of the Holy See,
# 17  Pre-Lateran period, comprising the initial day...
# 18  Vatican Library began an initial four-year pro...
# 19         manuscripts, to be made available online.
# 20          Hard Rock Cafe in New York's Times Square
# 21                     reaping a total $2 million. \n
# 22   pre-sale expectations of only $120,000 in sal...
# 23  Hoffman Ma, who bought the glove on behalf of ...
# 24                behalf of Ponte 16 Resort in Macau,
# 25            this gun-man, as Venters had called him
# 26  "Lassiter, will you be my rider?" Jane had ask...
# 27                     "I reckon so," he had replied.
# 28  She wanted him to take charge of her cattle an...
# 29  though she could not have spoken aloud all she...
# 30                      Whatever the price to be paid

# %%
test_data = json.load((open('/content/coqa/test.json')))
qas = json_normalize(test_data['data'], ['questions'], ['source', 'id', 'story'])
ans = json_normalize(test_data['data'], ['answers'],['id'])
test_df = pd.merge(qas,ans, left_on=['id','turn_id'], right_on=['id','turn_id'])
test_df.loc[10:30,['turn_id','input_text_x', 'input_text_y', 'span_text']]
# Out:
# <ipython-input-32-4292865034b1>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   qas = json_normalize(test_data['data'], ['questions'], ['source', 'id', 'story'])
# <ipython-input-32-4292865034b1>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   ans = json_normalize(test_data['data'], ['answers'],['id'])
#     turn_id                                       input_text_x  \
# 10       11  What did the other cats do when Cotton emerged...
# 11       12  Did they want Cotton to change the color of he...
# 12        1                      what was the name of the fish
# 13        2                     What looked like a birds belly
# 14        3                                      who said that
# 15        4                              Was Sharkie a friend?
# 16        5                           did they get the bottle?
# 17        6                                     What was in it
# 18        7                    Did a little boy write the note
# 19        8                            Who could read the note
# 20        9                     What did they do with the note
# 21       10                                did they write back
# 22       11                                  were they excited
# 23        1                                Who is at the door?
# 24        2                         Is she carrying something?
# 25        3                                              What?
# 26        4                                     Do I know her?
# 27        5                               Who is her daughter?
# 28        6                            Where does Nicole live?
# 29        7                     How is she related to the boy?
# 30        8                                What is in the bag?
#
#                                 input_text_y  \
# 10                           licked her face
# 11                                        no
# 12                                     Asta.
# 13                                  a bottle
# 14                                     Asta.
# 15                                       Yes
# 16                                       Yes
# 17                                    a note
# 18                                        No
# 19                               Asta's papa
# 20                                   unknown
# 21                                       yes
# 22                                   unknown
# 23  An elderly Chinese lady and a little boy
# 24                                       Yes
# 25                       a paper carrier bag
# 26                                       Yes
# 27                                    Nicole
# 28                                  Shanghai
# 29                                    mother
# 30                                      food
#
#                                             span_text
# 10                        Her sisters licked her face
# 11        We would never want you to be any other way
# 12                                              Asta.
# 13                                           a bottle
# 14         "It looks like a bird's belly," said Asta.
# 15                              Asta's friend Sharkie
# 16                          So they caught the bottle
# 17                                     It was a note.
# 18                    This note is from a little girl
# 19                          Asta's papa read the note
# 20                                            unknown
# 21  we can write a note to her. But you have to fi...
# 22                                            unknown
# 23  On the step, I find the elderly Chinese lady, ...
# 24                      she holds a paper carrier bag
# 25                                a paper carrier bag
# 26                                   I know this lady
# 27                               Her daughter, Nicole
# 28                         But she is now in Shanghai
# 29  She is the boy's grandmother, and her daughter...
# 30  a thermos with hot soup and a stainless-steel ...

# %%
test_df = test_df.loc[test_df['input_text_y']!='unknown']
test_df.loc[10:30,['turn_id','input_text_x','input_text_y','span_text']]
# Out:
#     turn_id                                       input_text_x  \
# 10       11  What did the other cats do when Cotton emerged...
# 11       12  Did they want Cotton to change the color of he...
# 12        1                      what was the name of the fish
# 13        2                     What looked like a birds belly
# 14        3                                      who said that
# 15        4                              Was Sharkie a friend?
# 16        5                           did they get the bottle?
# 17        6                                     What was in it
# 18        7                    Did a little boy write the note
# 19        8                            Who could read the note
# 21       10                                did they write back
# 23        1                                Who is at the door?
# 24        2                         Is she carrying something?
# 25        3                                              What?
# 26        4                                     Do I know her?
# 27        5                               Who is her daughter?
# 28        6                            Where does Nicole live?
# 29        7                     How is she related to the boy?
# 30        8                                What is in the bag?
#
#                                 input_text_y  \
# 10                           licked her face
# 11                                        no
# 12                                     Asta.
# 13                                  a bottle
# 14                                     Asta.
# 15                                       Yes
# 16                                       Yes
# 17                                    a note
# 18                                        No
# 19                               Asta's papa
# 21                                       yes
# 23  An elderly Chinese lady and a little boy
# 24                                       Yes
# 25                       a paper carrier bag
# 26                                       Yes
# 27                                    Nicole
# 28                                  Shanghai
# 29                                    mother
# 30                                      food
#
#                                             span_text
# 10                        Her sisters licked her face
# 11        We would never want you to be any other way
# 12                                              Asta.
# 13                                           a bottle
# 14         "It looks like a bird's belly," said Asta.
# 15                              Asta's friend Sharkie
# 16                          So they caught the bottle
# 17                                     It was a note.
# 18                    This note is from a little girl
# 19                          Asta's papa read the note
# 21  we can write a note to her. But you have to fi...
# 23  On the step, I find the elderly Chinese lady, ...
# 24                      she holds a paper carrier bag
# 25                                a paper carrier bag
# 26                                   I know this lady
# 27                               Her daughter, Nicole
# 28                         But she is now in Shanghai
# 29  She is the boy's grandmother, and her daughter...
# 30  a thermos with hot soup and a stainless-steel ...

# %%
train, val = train_test_split(train_df, test_size=0.2, random_state=42)
train.head()
# Out:
#                                  input_text_x  turn_id bad_turn_x     source  \
# 54860              So how did they get to 28?       20        NaN       race
# 69607      How much was the package in value?        9        NaN        cnn
# 94456  Did she think Adams was untrustworthy?        6        NaN        cnn
# 94333                  Who was he talking to?        3        NaN  gutenberg
# 47220   What does Pleistocene mean literally?       15        NaN  wikipedia
#
#                                    id  \
# 54860  39dd6s19jpbtyxnmal6qgea8wr2ze3
# 69607  3ii4upycoj7fsz8vructj3gjsr7qdt
# 94456  3wq3b2kge8gywyqusjv8nckbhrp1bi
# 94333  3qapzx2qn4d41w5gd7yx8eyxhj320q
# 47220  3nvc2eb65qzqj9xkpfnbjgx90ke3yk
#
#                                                    story  span_start  \
# 54860  Where did that number come from? Eleven and Tw...        1639
# 69607  Abidjan, Ivory Coast (CNN) -- The European Uni...          80
# 94456  ATLANTA, Georgia (CNN) -- Michele Trobaugh reg...         426
# 94333  CHAPTER V--"BLOODY AS THE HUNTER" \n\nThe lads...        1208
# 47220  The Pleistocene (, often colloquially referred...        1410
#
#        span_end                                          span_text  \
# 54860      1740  he took one day from each of the 30-day months...
# 69607        98                                  180 million euros
# 94456       462               She says she trusted him right away.
# 94333      1244               "Ye but deride me," answered Matcham
# 47220      1420                                         "Most New"
#
#                                             input_text_y bad_turn_y  \
# 54860  he took one day from each of the 30-day months...        NaN
# 69607                                  180 million euros        NaN
# 94456                                                 No        NaN
# 94333                                            Matcham        NaN
# 47220                                        "Most New."        NaN
#
#       q_first_word q_first_two_words
# 54860           so            so how
# 69607          how          how much
# 94456          did           did she
# 94333          who           who was
# 47220         what         what does

# %%
model_berttiny = EncoderDecoderModel.from_encoder_decoder_pretrained('prajjwal1/bert-tiny','prajjwal1/bert-tiny')
tokenizer = AutoTokenizer.from_pretrained('prajjwal1/bert-tiny')
# Out:
# Downloading:   0%|          | 0.00/285 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.8M [00:00<?, ?B/s]
# Some weights of the model checkpoint at prajjwal1/bert-tiny were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at prajjwal1/bert-tiny were not used when initializing BertLMHeadModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at prajjwal1/bert-tiny and are newly initialized: ['bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.self.value.weight', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.0.crossattention.output.dense.bias', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.self.query.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.0.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.0.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.1.crossattention.output.dense.weight', 'bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.0.crossattention.output.dense.weight', 'bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.1.crossattention.self.query.bias', 'bert.encoder.layer.1.crossattention.self.key.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
input_ids = tokenizer('train', return_tensors='pt').input_ids

# %%
labels = tokenizer('train', return_tensors='pt').input_ids

# %%
loss = model_berttiny(input_ids = input_ids, decoder_input_ids=labels, labels=labels).loss
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)

# %%
loss.backward()

# %%
model_berttiny.eval()
# Out:
# EncoderDecoderModel(
#   (encoder): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 128, padding_idx=0)
#       (position_embeddings): Embedding(512, 128)
#       (token_type_embeddings): Embedding(2, 128)
#       (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=128, out_features=128, bias=True)
#               (key): Linear(in_features=128, out_features=128, bias=True)
#               (value): Linear(in_features=128, out_features=128, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=128, out_features=128, bias=True)
#               (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=128, out_features=512, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=512, out_features=128, bias=True)
#             (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=128, out_features=128, bias=True)
#               (key): Linear(in_features=128, out_features=128, bias=True)
#               (value): Linear(in_features=128, out_features=128, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=128, out_features=128, bias=True)
#               (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=128, out_features=512, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=512, out_features=128, bias=True)
#             (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=128, out_features=128, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): BertLMHeadModel(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 128, padding_idx=0)
#         (position_embeddings): Embedding(512, 128)
#         (token_type_embeddings): Embedding(2, 128)
#         (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (crossattention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=128, out_features=512, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=512, out_features=128, bias=True)
#               (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (crossattention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=True)
#                 (value): Linear(in_features=128, out_features=128, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=128, out_features=128, bias=True)
#                 (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=128, out_features=512, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=512, out_features=128, bias=True)
#               (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (cls): BertOnlyMLMHead(
#       (predictions): BertLMPredictionHead(
#         (transform): BertPredictionHeadTransform(
#           (dense): Linear(in_features=128, out_features=128, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=128, out_features=30522, bias=True)
#       )
#     )
#   )
# )

# %%
greedy_output = model_berttiny.generate(input_ids, decoder_start_token_id=model_berttiny.config.decoder.pad_token_id)
